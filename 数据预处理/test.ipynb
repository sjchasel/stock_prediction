# %%
import pandas as pd
def code_stock(code):
    agu = pd.read_excel('C:/Users/zhaoyu/Desktop/全部A股代码和名字.xlsx')
    return list(agu[agu['Stkcd'] == int(code)]['Stknme'])[0]
code_stock('900948')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-8fa095aa3787> in <module>
#       3     agu = pd.read_excel('C:/Users/zhaoyu/Desktop/全部A股代码和名字.xlsx')
#       4     return list(agu[agu['Stkcd'] == int(code)]['Stknme'])[0]
# ----> 5 code_stock('900948')
#
# <ipython-input-1-8fa095aa3787> in code_stock(code)
#       1 import pandas as pd
#       2 def code_stock(code):
# ----> 3     agu = pd.read_excel('C:/Users/zhaoyu/Desktop/全部A股代码和名字.xlsx')
#       4     return list(agu[agu['Stkcd'] == int(code)]['Stknme'])[0]
#       5 code_stock('900948')
#
# ~\Anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     206                 else:
#     207                     kwargs[new_arg_name] = new_arg_value
# --> 208             return func(*args, **kwargs)
#     209
#     210         return wrapper
#
# ...

# %%
import pandas as pd
path = '钢铁.csv'
gt = pd.read_csv(path)
gt
# Out:
#        Unnamed: 0        date    code   open   high    low  close  preclose  \
# 0               0    2018-1-2     708  11.45  11.84  11.35  11.72     11.43
# 1               1    2018-1-3     708  11.65  11.75  11.58  11.67     11.72
# 2               2    2018-1-4     708  11.61  11.98  11.61  11.81     11.67
# 3               3    2018-1-5     708  11.75  11.83  11.68  11.72     11.81
# 4               4    2018-1-8     708  11.70  11.93  11.65  11.86     11.72
# ...           ...         ...     ...    ...    ...    ...    ...       ...
# 25084       25084  2020-12-25  603995  27.10  27.10  25.28  25.40     27.10
# 25085       25085  2020-12-28  603995  25.50  25.88  24.38  25.16     25.40
# 25086       25086  2020-12-29  603995  25.10  26.36  24.70  25.50     25.16
# 25087       25087  2020-12-30  603995  26.18  26.18  24.58  25.41     25.50
# 25088       25088  2020-12-31  603995  25.39  26.44  25.20  26.02     25.41
#
# ...

# %%
gt = gt[gt['code']!=601686]
gt = gt[gt['code']!=603995]
gt.drop(labels=['Unnamed: 0'],axis=1,inplace=True)

# %%
gt.to_csv('钢铁行业34支股票.csv', index=False)

# %%
zzy = pd.read_csv('种植业.csv')
codelist = list(zzy['code'].unique())
print(codelist)
for i in codelist:
    data = zzy[zzy['code']==i]
    print(len(data))
# Out:
# [713, 998, 2024, 2041, 2772, 300087, 300189, 300511, 600108, 600313, 600354, 600359, 600371, 600506, 600540, 600598, 601118, 601952, 603336]
# 730
# 730
# 730
# 730
# 730
# 730
# 730
# 730
# 730
# 730
# 730
# 730
# 730
# 730
# 730
# 730
# 730
# 730
# 730

# %%
zzy
# Out:
#        Unnamed: 0        date    code   open   high    low  close  preclose  \
# 0               0    2018-1-2     713   6.88   6.91   6.84   6.89      6.88
# 1               1    2018-1-3     713   6.91   6.95   6.87   6.94      6.89
# 2               2    2018-1-4     713   6.97   6.98   6.91   6.92      6.94
# 3               3    2018-1-5     713   6.94   7.01   6.92   6.99      6.92
# 4               4    2018-1-8     713   6.95   7.04   6.88   6.97      6.99
# ...           ...         ...     ...    ...    ...    ...    ...       ...
# 13865       13865  2020-12-25  603336  11.32  11.38  10.50  10.63     11.60
# 13866       13866  2020-12-28  603336  10.56  10.94  10.41  10.78     10.63
# 13867       13867  2020-12-29  603336  10.70  10.78  10.45  10.51     10.78
# 13868       13868  2020-12-30  603336  10.60  10.72  10.20  10.48     10.51
# 13869       13869  2020-12-31  603336  10.37  10.75  10.34  10.57     10.48
#
# ...

# %%
zzy.drop(labels=['Unnamed: 0'],axis=1,inplace=True)
zzy.to_csv('种植业19支股票.csv', index=False)

# %%
hxyl = pd.read_csv('化学原料.csv')
codelist = list(hxyl['code'].unique())
print(codelist)
for i in codelist:
    data = hxyl[hxyl['code']==i]
    print(i)
    print(len(data))
    print('--------------')
# Out:
# [422, 510, 545, 635, 683, 707, 818, 822, 2002, 2053, 2092, 2125, 2386, 2648, 2805, 300285, 300409, 300655, 600075, 600277, 600319, 600328, 600367, 600409, 600618, 600722, 600929, 601216, 601568, 601678, 603067, 603077, 603299, 603928, 603938]
# 422
# 730
# --------------
# 510
# 730
# --------------
# 545
# 730
# --------------
# 635
# 730
# --------------
# 683
# 730
# --------------
# 707
# 730
# --------------
# 818
# 730
# --------------
# 822
# 730
# --------------
# 2002
# 730
# --------------
# 2053
# 730
# --------------
# 2092
# 730
# --------------
# 2125
# 730
# --------------
# 2386
# 730
# --------------
# 2648
# 730
# --------------
# 2805
# 730
# --------------
# 300285
# 730
# --------------
# 300409
# 730
# --------------
# 300655
# 730
# --------------
# 600075
# 730
# --------------
# 600277
# 730
# --------------
# 600319
# 730
# --------------
# 600328
# 730
# --------------
# 600367
# 730
# --------------
# 600409
# 730
# --------------
# 600618
# 730
# ...

# %%
hxyl = hxyl[hxyl['code']!=601568]
hxyl = hxyl[hxyl['code']!=600929]
hxyl.drop(labels=['Unnamed: 0'],axis=1,inplace=True)
hxyl.to_csv('化学原料33支股票.csv', index=False)

# %%
len(codelist)
# Out:
# 35

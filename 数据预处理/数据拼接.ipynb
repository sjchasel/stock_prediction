# %%
import pandas as pd
import numpy as np

# %%
hxyl_k = pd.read_csv('../化学原料35个企业近三年的日k数据.csv')
zzy_k = pd.read_csv('../种植业19个企业近三年的日k数据.csv')
gt_k = pd.read_csv('../钢铁36个企业近三年的日k数据.csv')
com = pd.read_csv('../text_mining/3年3行业的个股研报词句段特征结果.csv')
ind = pd.read_csv('../text_mining/3年3行业的行业研报词句段特征.csv')

# %%
hxyl_k.drop(labels=['Unnamed: 0'],axis=1,inplace=True)
hxyl_k = hxyl_k.set_index('date')
hxyl_k.head()
# Out:
#                  code   open   high    low  close  preclose    volume  \
# date
# 2018-01-02  sz.002648  16.60  17.58  16.51  17.28     16.60  17201569
# 2018-01-03  sz.002648  17.35  18.14  17.33  17.67     17.28  20287342
# 2018-01-04  sz.002648  17.70  18.97  17.68  18.46     17.67  24306722
# 2018-01-05  sz.002648  18.42  18.59  18.00  18.29     18.46  14686623
# 2018-01-08  sz.002648  18.29  19.47  18.15  19.01     18.29  17181733
#
#                   amount  adjustflag      turn  tradestatus    pctChg  isST
# date
# 2018-01-02  2.960830e+08           3  2.146780            1  4.096387     0
# 2018-01-03  3.596242e+08           3  2.531889            1  2.256941     0
# 2018-01-04  4.439240e+08           3  3.033513            1  4.470849     0
# 2018-01-05  2.684285e+08           3  1.832911            1 -0.920900     0
# 2018-01-08  3.259666e+08           3  2.144305            1  3.936574     0

# %%
zzy_k.drop(labels=['Unnamed: 0'],axis=1,inplace=True)
zzy_k = zzy_k.set_index('date')
zzy_k.head()
# Out:
#                  code   open   high    low  close  preclose    volume  \
# date
# 2018-01-02  sh.601952  14.14  14.20  13.42  13.56     14.13  22351520
# 2018-01-03  sh.601952  13.52  13.69  13.34  13.67     13.56  15448136
# 2018-01-04  sh.601952  13.60  13.64  13.45  13.49     13.67  11150687
# 2018-01-05  sh.601952  13.49  13.62  13.42  13.53     13.49  10075909
# 2018-01-08  sh.601952  13.52  13.53  13.10  13.28     13.53  14617468
#
#                  amount  adjustflag      turn  tradestatus    pctChg  isST
# date
# 2018-01-02  304363065.0           3  8.596738            1 -4.033968     0
# 2018-01-03  208750569.0           3  5.941591            1  0.811207     0
# 2018-01-04  150804825.0           3  4.288726            1 -1.316754     0
# 2018-01-05  136507736.0           3  3.875350            1  0.296516     0
# 2018-01-08  193470193.0           3  5.622103            1 -1.847746     0

# %%
gt_k.drop(labels=['Unnamed: 0'],axis=1,inplace=True)
gt_k = gt_k.set_index('date')
gt_k.head()
# Out:
#                  code   open   high    low  close  preclose    volume  \
# date
# 2020-12-04  sh.601686  15.43  18.52  15.43  18.52     12.86   4806557
# 2020-12-07  sh.601686  18.52  18.53  16.67  16.95     18.52  57382294
# 2020-12-08  sh.601686  16.27  16.77  15.52  15.64     16.95  37940885
# 2020-12-09  sh.601686  15.52  16.50  15.28  16.10     15.64  31192659
# 2020-12-10  sh.601686  15.70  17.61  15.62  16.50     16.10  32936912
#
#                   amount  adjustflag     turn  tradestatus   pctChg  isST
# date
# 2020-12-04  8.895162e+07           3   3.3849            1  44.0124     0
# 2020-12-07  9.942266e+08           3  40.4101            1  -8.4773     0
# 2020-12-08  6.060229e+08           3  26.7189            1  -7.7286     0
# 2020-12-09  5.000961e+08           3  21.9667            1   2.9412     0
# 2020-12-10  5.501648e+08           3  23.1950            1   2.4845     0

# %%
gt_k.loc['2020-12-04']
# Out:
#                  code   open   high    low  close  preclose     volume  \
# date
# 2020-12-04  sh.601686  15.43  18.52  15.43  18.52     12.86    4806557
# 2020-12-04  sh.603995  28.30  28.72  28.19  28.65     28.50     785300
# 2020-12-04  sh.600808   2.79   2.80   2.74   2.77      2.79   36417260
# 2020-12-04  sh.600282   3.28   3.28   3.21   3.27      3.27   35884236
# 2020-12-04  sh.600019   6.17   6.17   5.90   6.07      6.20  165204126
# 2020-12-04  sh.600399  11.89  11.89  11.51  11.61     11.95   22411044
# 2020-12-04  sz.002318  10.02  10.22   9.85  10.12     10.10   19184555
# 2020-12-04  sz.002478   4.80   4.82   4.79   4.81      4.82    3064805
# 2020-12-04  sz.000778   3.88   3.88   3.81   3.83      3.87   25671074
# 2020-12-04  sz.000708  20.92  21.05  20.73  20.84     20.90    3167477
# 2020-12-04  sz.000825   3.76   3.76   3.70   3.74      3.75   16618779
# 2020-12-04  sz.000898   3.14   3.16   3.08   3.16      3.13   44016171
# ...

# %%
com_sen = pd.read_csv('C:/Users/12968/Desktop/数据科学实战-stock prediction/company_quality_val.csv')
ind_sen = pd.read_csv('C:/Users/12968/Desktop/数据科学实战-stock prediction/industry_quality_val.csv')

# %%
com1 = com_sen[com_sen['ind']=='种植业']
com2 = com_sen[com_sen['ind']=='化学原料']
com3 = com_sen[com_sen['ind']=='钢铁']
company_sen = pd.concat([com1,com2,com3],axis=0,ignore_index=True)
company_sen.head()
# Out:
#      id cate                                            content        date  \
# 0   991   公司      本报告导读： ???\r\r\r\r\n    土地流转速度加快，行业容量空间大，足...  2018-08-16
# 1   995   公司  　　报告要点 ???\r\r\r\r\n　　事件描述 ???\r\r\r\r\n　　我们认为...  2017-01-06
# 2  1010   公司      事件: ???\r\r\r\r\n    北大荒(600598.CH/人民币 19....  2015-08-25
# 3  1011   公司                                                  ·  2015-01-23
# 4  1012   公司      事件: ???\r\r\r\r\n    北大荒(600598.CH/人民币 15....  2015-08-28
#
#    ind           ins   person stock_name  stock_num  \
# 0  种植业  国泰君安证券股份有限公司  钟凯锋/鲁家瑞       苏垦农发   601952.0
# 1  种植业    长江证券股份有限公司       陈佳        北大荒   600598.0
# 2  种植业  中银国际证券有限责任公司  杨天明/程一胜        北大荒   600598.0
# 3  种植业    长江证券股份有限公司   陈佳/高辰星        北大荒   600598.0
# 4  种植业  中银国际证券有限责任公司  杨天明/程一胜        北大荒   600598.0
#
#                                       title  quality_val  pos_num  neg_num  \
# 0    【深度系列报告二】苏垦农发(601952)：一体化种植的龙头 量价齐升的苏垦     6.646659       41        5
# ...

# %%
com.head()
# Out:
#    Unnamed: 0        avg_sentence  avg_stroke        date  four_word  \
# 0           0   45.93333333333333    7.321101  2018-08-16   0.026119
# 1           1   45.93333333333333    7.321101  2018-08-16   0.026119
# 2           2   41.93333333333333    7.531955  2020-12-17   0.081633
# 3           3  60.642857142857146    7.388554  2020-12-04   0.022222
# 4           4                58.0    7.258469  2020-11-02   0.033766
#
#         function_ratio  ind             n_ratio  nine_stroke  \
# 0  0.08056872037914692  种植业  0.2772511848341232     0.223853
# 1  0.08056872037914692  种植业  0.2772511848341232     0.223853
# 2  0.07754010695187166  种植业  0.2887700534759358     0.278195
# 3   0.0851063829787234  种植业  0.2727272727272727     0.215361
# 4  0.05057803468208093  种植业  0.2514450867052023     0.237139
#
#                no_text        sen_per_para stock_name  stock_num  sum_para  \
# 0  0.23259052924791088  2.5555555555555554       苏垦农发   601952.0       9.0
# ...

# %%
for i in range(len(com)):
    title = com['title'][i]
    com['pos_num'][i] = list(company_sen[company_sen['title']==title]['pos_num'])[0]
    com['quality_val'][i] = list(company_sen[company_sen['title']==title]['quality_val'])[0]
    com['neg_num'][i] = list(company_sen[company_sen['title']==title]['neg_num'])[0]
    com['bias'][i] = list(company_sen[company_sen['title']==title]['bias'])[0]
# Out:
# C:\Users\12968\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\12968\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# C:\Users\12968\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
#com.drop(labels=['Unnamed: 0'],axis=1,inplace=True)
#com.to_csv('3年3行业个股研报除语法树外特征.csv')
com
# Out:
#             avg_sentence  avg_stroke        date  four_word  \
# 0      45.93333333333333    7.321101  2018-08-16   0.026119
# 1      45.93333333333333    7.321101  2018-08-16   0.026119
# 2      41.93333333333333    7.531955  2020-12-17   0.081633
# 3     60.642857142857146    7.388554  2020-12-04   0.022222
# 4                   58.0    7.258469  2020-11-02   0.033766
# ...                  ...         ...         ...        ...
# 2600   67.58333333333333    7.382403  2018-01-09   0.064748
# 2601  63.666666666666664    7.418087  2018-01-08   0.029101
# 2602               35.76    7.310897  2018-01-08   0.025237
# 2603   60.92857142857143    7.483501  2018-01-05   0.070988
# 2604               36.05    7.426644  2018-01-02   0.020619
#
#             function_ratio  ind              n_ratio  nine_stroke  \
# 0      0.08056872037914692  种植业   0.2772511848341232     0.223853
# 1      0.08056872037914692  种植业   0.2772511848341232     0.223853
# ...

# %%
ind1 = ind_sen[ind_sen['ind']=='种植业']
ind2 = ind_sen[ind_sen['ind']=='化学原料']
ind3 = ind_sen[ind_sen['ind']=='钢铁']
industry_sen = pd.concat([ind1,ind2,ind3],axis=0,ignore_index=True)
industry_sen.head()
# Out:
#    Unnamed: 0 cate                                            content  \
# 0        3301   行业  　　本周关注 ???\r\r\r\n　　据中国饲料工业协会，根据已填报企业测算，2021 年...
# 1        3309   行业      全球： ???\r\r\r\n    （1）短期：全球供需缺口扩大，主要系后疫情时代...
# 2        3310   行业  　　投资要点 ???\r\r\r\n　　事件：3 月24 日，瑞典服装品牌H&M 在其官网发...
# 3        3314   行业  　　事项： ???\r\r\r\n　　农业农村部发布《关于鼓励农业转基因生物原始创新和规范生...
# 4        3316   行业      种子是农业生产芯片，迎来新一轮政策红利 ???\r\r\r\n    种子处于种植产...
#
#          date  ind         ins person                               title  \
# 0  2021-04-26  种植业  东方证券股份有限公司    张斌梅          农业2020年第18周周报：1-2月饲料销量情况披露
# 1  2021-04-02  种植业  中泰证券股份有限公司    范劲松                    行业深度报告：棉花行业的研究框架
# 2  2021-03-30  种植业  中泰证券股份有限公司    范劲松               种植行业点评报告：“新疆棉遭抵制事件”点评
# 3  2021-02-19  种植业  国信证券股份有限公司    鲁家瑞  种业行业点评系列报告：农业部鼓励转基因育种研发看好行业周期与成长共振
# 4  2021-01-31  种植业  国信证券股份有限公司    鲁家瑞        种植业种业深度报告系列二：高粮价出业绩 转基因落地抬估值
#
#    quality_val  pos_num  neg_num      bias
# 0     6.020875       13        5  0.444442
# ...

# %%
ind.head()
# Out:
#    Unnamed: 0        avg_sentence  avg_stroke        date  four_word  \
# 0           0    47.1764705882353    7.610390  2020-12-24   0.009146
# 1           1  44.666666666666664    7.508735  2020-12-21   0.026393
# 2           2  107.16666666666667    7.705664  2020-12-21   0.047431
# 3           3   59.30769230769231    7.409336  2020-08-14   0.025926
# 4           4               56.25    7.674276  2020-08-11   0.030965
#
#         function_ratio  ind              n_ratio  nine_stroke  \
# 0  0.09745762711864407  种植业   0.2966101694915254     0.178932
# 1  0.08058252427184466  种植业  0.29902912621359223     0.229210
# 2  0.06267029972752043  种植业   0.3201634877384196     0.240483
# 3  0.06896551724137931  种植业   0.2850574712643678     0.233393
# 4  0.05070118662351672  种植业   0.2632146709816613     0.263389
#
#                no_text        sen_per_para  sum_para  \
# 0  0.12926829268292683                 3.0       8.0
# 1  0.19831932773109243   3.923076923076923      13.0
# ...

# %%
industry_sen.iloc[0,8]
# Out:
# 6.020874558822255

# %%
for i in range(len(ind)):
    title = ind['title'][i]
    ind['pos_num'][i] = industry_sen[industry_sen['title']==title].iloc[0,9]
    ind['quality_val'][i] = industry_sen[industry_sen['title']==title].iloc[0,8]
    ind['neg_num'][i] = industry_sen[industry_sen['title']==title].iloc[0,10]
    ind['bias'][i] = industry_sen[industry_sen['title']==title].iloc[0,11]
# Out:
# C:\Users\12968\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
# C:\Users\12968\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\12968\Anaconda3\lib\site-packages\ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':
# ...

# %%
ind.to_csv('3年3行业行业研报除语法树外特征.csv')

# %% [markdown]
# # 与k线数据拼接

# %%
hxyl_k = pd.read_csv('../化学原料35个企业近三年的日k数据.csv')
zzy_k = pd.read_csv('../种植业19个企业近三年的日k数据.csv')
gt_k = pd.read_csv('../钢铁36个企业近三年的日k数据.csv')
hxyl_k.drop(labels=['Unnamed: 0'],axis=1,inplace=True)
zzy_k.drop(labels=['Unnamed: 0'],axis=1,inplace=True)
gt_k.drop(labels=['Unnamed: 0'],axis=1,inplace=True)
hxyl_k['ind'] = '化学原料'
zzy_k['ind'] = '种植业'
gt_k['ind'] = '钢铁'

# %%
k_data = pd.concat([hxyl_k,zzy_k,gt_k],axis=0,ignore_index=True)

# %%
k_data.head(2)
# Out:
#          date       code   open   high    low  close  preclose    volume  \
# 0  2018-01-02  sz.002648  16.60  17.58  16.51  17.28     16.60  17201569
# 1  2018-01-03  sz.002648  17.35  18.14  17.33  17.67     17.28  20287342
#
#          amount  adjustflag      turn  tradestatus    pctChg  isST   ind
# 0  2.960830e+08           3  2.146780            1  4.096387     0  化学原料
# 1  3.596242e+08           3  2.531889            1  2.256941     0  化学原料

# %%
ind.head(2)
# Out:
#    Unnamed: 0        avg_sentence  avg_stroke        date  four_word  \
# 0           0    47.1764705882353    7.610390  2020-12-24   0.009146
# 1           1  44.666666666666664    7.508735  2020-12-21   0.026393
#
#         function_ratio  ind              n_ratio  nine_stroke  \
# 0  0.09745762711864407  种植业   0.2966101694915254     0.178932
# 1  0.08058252427184466  种植业  0.29902912621359223     0.229210
#
#                no_text  ... sum_para                           title word_max  \
# 0  0.12926829268292683  ...      8.0             种植业Ⅱ：EDV重塑行业 头部最为受益     14.0
# 1  0.19831932773109243  ...     13.0  种植链行业点评系列一：农业迎政策驱动催化 种业与种植充分受益     15.0
#
#             word_mean word_phrase            word_var pos_num  quality_val  \
# 0  1.7588235294117647    0.146853   3.077128027681661    46.0     6.824628
# 1  1.8849557522123894    0.207080  3.9484167384551117    54.0     7.590760
#
#    neg_num      bias
# 0      6.0  0.769229
# 1     26.0  0.350000
#
# [2 rows x 21 columns]

# %%
com.columns
# Out:
# Index(['avg_sentence', 'avg_stroke', 'date', 'four_word', 'function_ratio',
#        'ind', 'n_ratio', 'nine_stroke', 'no_text', 'sen_per_para',
#        'stock_name', 'stock_num', 'sum_para', 'title', 'word_max', 'word_mean',
#        'word_phrase', 'word_var', 'pos_num', 'quality_val', 'neg_num', 'bias'],
#       dtype='object')

# %%
k_data['avg_sentence'] = 0.000000
k_data['avg_stroke'] = 0.00000
k_data['four_word'] = 0.00000
k_data['function_ratio'] = 0.00000
k_data['n_ratio'] = 0.00000
k_data['nine_stroke'] = 0.00000
k_data['no_text'] = 0.00000
k_data['sen_per_para'] = 0.00000
k_data['sum_para'] = 0.00000
k_data['word_max'] = 0.00000
k_data['word_mean'] = 0.00000
k_data['word_phrase'] = 0.00000
k_data['word_var'] = 0.00000
k_data['pos_num'] = 0.00000
k_data['quality_val'] = 0.00000
k_data['neg_num'] = 0.00000
k_data['bias'] = 0.00000
for i in range(len(k_data)):
    date = k_data['date'][i]
    #print(date)
    ind_name = k_data['ind'][i]
    #print(ind_name)
    code =  np.float64(k_data['code'][i][3:])
    #print(code)
    
    #
    k_data['avg_sentence'][i] += np.sum(list(float(i) for i in ind[ind['date']==date][ind['ind']==ind_name]['avg_sentence']))
    print(k_data['avg_sentence'][i])
    k_data['avg_stroke'][i] += np.sum(list(float(i) for i in ind[ind['date']==date][ind['ind']==ind_name]['avg_stroke']))
    k_data['four_word'][i] += np.sum(list(float(i) for i in ind[ind['date']==date][ind['ind']==ind_name]['four_word']))
    k_data['function_ratio'][i] += np.sum(list(float(i) for i in ind[ind['date']==date][ind['ind']==ind_name]['function_ratio']))
    k_data['n_ratio'][i] += np.sum(list(float(i) for i in ind[ind['date']==date][ind['ind']==ind_name]['n_ratio']))
    k_data['nine_stroke'][i] += np.sum(list(float(i) for i in ind[ind['date']==date][ind['ind']==ind_name]['nine_stroke']))
    k_data['no_text'][i] += np.sum(list(float(i) for i in ind[ind['date']==date][ind['ind']==ind_name]['no_text']))
    k_data['sen_per_para'][i] += np.sum(list(float(i) for i in ind[ind['date']==date][ind['ind']==ind_name]['sen_per_para']))
    k_data['sum_para'][i] += np.sum(list(float(i) for i in ind[ind['date']==date][ind['ind']==ind_name]['sum_para']))
    k_data['word_max'][i] += np.sum(list(float(i) for i in ind[ind['date']==date][ind['ind']==ind_name]['word_max']))
    k_data['word_mean'][i] += np.sum(list(float(i) for i in ind[ind['date']==date][ind['ind']==ind_name]['word_mean']))
    k_data['word_phrase'][i] += np.sum(list(float(i) for i in ind[ind['date']==date][ind['ind']==ind_name]['word_phrase']))
    k_data['word_var'][i] += np.sum(list(float(i) for i in ind[ind['date']==date][ind['ind']==ind_name]['word_var']))
    k_data['pos_num'][i] += np.sum(list(float(i) for i in ind[ind['date']==date][ind['ind']==ind_name]['pos_num']))
    k_data['quality_val'][i] += np.sum(list(float(i) for i in ind[ind['date']==date][ind['ind']==ind_name]['quality_val']))
    k_data['neg_num'][i] += np.sum(list(float(i) for i in ind[ind['date']==date][ind['ind']==ind_name]['neg_num']))
    k_data['bias'][i] += np.sum(list(float(i) for i in ind[ind['date']==date][ind['ind']==ind_name]['bias']))
    
    #com
    k_data['avg_sentence'][i] += np.sum(list(float(i) for i in com[com['date']==date][com['stock_num']==code]['avg_sentence']))
    print(k_data['avg_sentence'][i])
    k_data['avg_stroke'][i] += np.sum(list(float(i) for i in com[com['date']==date][com['stock_num']==code]['avg_stroke']))
    k_data['four_word'][i] += np.sum(list(float(i) for i in com[com['date']==date][com['stock_num']==code]['four_word']))
    k_data['function_ratio'][i] += np.sum(list(float(i) for i in com[com['date']==date][com['stock_num']==code]['function_ratio']))
    k_data['n_ratio'][i] += np.sum(list(float(i) for i in com[com['date']==date][com['stock_num']==code]['n_ratio']))
    k_data['nine_stroke'][i] += np.sum(list(float(i) for i in com[com['date']==date][com['stock_num']==code]['nine_stroke']))
    k_data['no_text'][i] += np.sum(list(float(i) for i in com[com['date']==date][com['stock_num']==code]['no_text']))
    k_data['sen_per_para'][i] += np.sum(list(float(i) for i in com[com['date']==date][com['stock_num']==code]['sen_per_para']))
    k_data['sum_para'][i] += np.sum(list(float(i) for i in com[com['date']==date][com['stock_num']==code]['sum_para']))
    k_data['word_max'][i] += np.sum(list(float(i) for i in com[com['date']==date][com['stock_num']==code]['word_max']))
    k_data['word_mean'][i] += np.sum(list(float(i) for i in com[com['date']==date][com['stock_num']==code]['word_mean']))
    k_data['word_phrase'][i] += np.sum(list(float(i) for i in com[com['date']==date][com['stock_num']==code]['word_phrase']))
    k_data['word_var'][i] += np.sum(list(float(i) for i in com[com['date']==date][com['stock_num']==code]['word_var']))
    k_data['pos_num'][i] += np.sum(list(float(i) for i in com[com['date']==date][com['stock_num']==code]['pos_num']))
    k_data['quality_val'][i] += np.sum(list(float(i) for i in com[com['date']==date][com['stock_num']==code]['quality_val']))
    k_data['neg_num'][i] += np.sum(list(float(i) for i in com[com['date']==date][com['stock_num']==code]['neg_num']))
    k_data['bias'][i] += np.sum(list(float(i) for i in com[com['date']==date][com['stock_num']==code]['bias']))

# %%
list(float(i) for i in ind[ind['date']=='2018-02-06'][ind['ind']=='化学原料']['avg_sentence'])
# Out:
# C:\Users\12968\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
# [58.0]

# %%
type(com['stock_num'][0])
# Out:
# numpy.float64

# %%
stock_code = np.float64(k_data['code'][0][3:])

# %%
type(stock_code)
# Out:
# numpy.float64

# %%
k_data.to_csv('除语法树与交易因子外的数据.csv')
